# %% [markdown]
# <a href="https://colab.research.google.com/github/chhoures-netizen/INFO450/blob/main/Lesson5/Lesson5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url="https://raw.githubusercontent.com/chhoures-netizen/INFO450/refs/heads/main/Lesson5/Soccer.json"
response=requests.get(url)
response.status_code #200 means no error
response.raise_for_status() #if theres an error, stop and tell me what it is
data=response.json()
data
data.keys()
data['matches'][64]
# Out:
# {'round': 'First Stage, Group K',
#  'date': '2026-06-27',
#  'time': '19:30 UTC-4',
#  'team1': 'Congo DR',
#  'team2': 'Uzbekistan',
#  'score': {'ft': [3, 1], 'ht': [0, 1]},
#  'goals1': [{'name': 'Yoane WISSA', 'minute': '68', 'penalty': True},
#   {'name': 'Fiston MAYELE', 'minute': '78'},
#   {'name': 'Yoane WISSA', 'minute': '90+1'}],
#  'goals2': [{'name': 'Eldor SHOMURODOV', 'minute': '10'}],
#  'ground': 'Atlanta Stadium, Atlanta',
#  'attendance': 68239,
#  'lineup': [{'starter': [{'name': 'Lionel MPASI'},
#     {'name': 'Aaron WAN-BISSAKA'},
#     {'name': 'Axel Tuanzebe'},
#     {'name': 'Chancel MBEMBA', 'captain': True},
#     {'name': 'Arthur MASUAKU'},
#     {'name': 'Nathanael MBUKU'},
#     {'name': 'Samuel Moutoussamy'},
#     {'name': 'Noah SADIKI'},
#     {'name': 'Brian CIPENGA'},
#     {'name': 'Cedric BAKAMBU'},
#     {'name': 'Yoane WISSA'}],
#    'bench': [{'name': 'Joris KAYEMBE'},
#     {'name': 'Meschack ELIA'},
#     {'name': 'Ngalayel MUKAU'},
# ...
